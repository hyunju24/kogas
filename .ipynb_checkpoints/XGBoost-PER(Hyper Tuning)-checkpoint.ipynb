# %%
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %%
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv('월별공급량및비중all.csv')
print(data)
data["ID"] = pd.date_range("1996-01-01", "2020-12-01", freq="MS")
# Out:
#      YEAR  MONTH  도시가스(톤)_민수용  도시가스(톤)_산업용  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0    1996      1       605519        83809      689328     0.87842     0.12158
# 1    1996      2       566323        70427      636750     0.88940     0.11060
# 2    1996      3       477514        62652      540166     0.88401     0.11599
# 3    1996      4       337794        47050      384844     0.87774     0.12226
# 4    1996      5       184522        30709      215231     0.85732     0.14268
# ..    ...    ...          ...          ...         ...         ...         ...
# 295  2020      8       398661       457970      856631     0.46538     0.53462
# 296  2020      9       380235       525619      905853     0.41975     0.58025
# 297  2020     10       616682       600890     1217571     0.50649     0.49352
# 298  2020     11      1093747       665901     1759648     0.62157     0.37843
# 299  2020     12      1921404       811928     2733332     0.70295     0.29705
#
# [300 rows x 7 columns]

# %%
civil = data[['YEAR', 'MONTH', "도시가스(톤)_민수용"]]
civil.index = data["ID"]
print(civil.head())
# Out:
#             YEAR  MONTH  도시가스(톤)_민수용
# ID
# 1996-01-01  1996      1       605519
# 1996-02-01  1996      2       566323
# 1996-03-01  1996      3       477514
# 1996-04-01  1996      4       337794
# 1996-05-01  1996      5       184522

# %%
civil['도시가스(톤)_민수용'].plot(style='-',
          figsize=(15, 5),
          color=color_pal[0],
          title='gas_personal')

plt.show()

# %%
split_date = '2017-12-01'
train = civil.loc[civil.index <= split_date].copy()
test = civil.loc[civil.index > split_date].copy()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline(split_date, color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits=7, test_size=12, gap=0)
civil = civil.sort_index()

# %%
fig, axs = plt.subplots(7, 1, figsize=(15, 15), sharex=True)

fold = 0
for train_idx, val_idx in tss.split(civil):
    train = civil.iloc[train_idx]
    test = civil.iloc[val_idx]
    train['도시가스(톤)_민수용'].plot(ax=axs[fold],
                          label='Training Set',
                          title=f'Data Train/Test Split Fold {fold}')
    test['도시가스(톤)_민수용'].plot(ax=axs[fold],
                         label='Test Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold += 1
plt.show()

# %%
def add_lags(df):
    df['lag1'] = df['도시가스(톤)_민수용'].shift(12)
    df['lag2'] = df['도시가스(톤)_민수용'].shift(24)
    return df

# %%
civil = add_lags(civil)

# %%
tss = TimeSeriesSplit(n_splits=7, test_size=12, gap=0)
civil = civil.sort_index()

fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(civil):
    train = civil.iloc[train_idx]
    test = civil.iloc[val_idx]

    FEATURES = ['MONTH', 'lag1','lag2']
    TARGET = '도시가스(톤)_민수용'

    X_train = train[FEATURES]
    y_train = train[TARGET]

    X_test = test[FEATURES]
    y_test = test[TARGET]

    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                           n_estimators=460,
                           objective='reg:squarederror',
                           max_depth=3,
                           eval_metric='mae',
                           learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)

    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
# Out:
# [0]	validation_0-mae:708231.68750	validation_1-mae:834893.56250
# [100]	validation_0-mae:271401.71875	validation_1-mae:270673.25000
# [200]	validation_0-mae:113245.50781	validation_1-mae:89136.63281
# [300]	validation_0-mae:59018.87109	validation_1-mae:62342.87891
# [400]	validation_0-mae:41569.08984	validation_1-mae:79931.77344
# [459]	validation_0-mae:37500.30469	validation_1-mae:86589.11719
# [0]	validation_0-mae:714902.25000	validation_1-mae:826873.93750
# [100]	validation_0-mae:273466.56250	validation_1-mae:294380.21875
# [200]	validation_0-mae:114410.78906	validation_1-mae:89680.28906
# [300]	validation_0-mae:60082.92969	validation_1-mae:36784.67578
# [400]	validation_0-mae:43978.52734	validation_1-mae:35742.20703
# [459]	validation_0-mae:40493.23828	validation_1-mae:39019.20703
# [0]	validation_0-mae:720498.75000	validation_1-mae:868480.50000
# [100]	validation_0-mae:275168.37500	validation_1-mae:327126.25000
# [200]	validation_0-mae:114167.62500	validation_1-mae:135953.12500
# [300]	validation_0-mae:59922.81641	validation_1-mae:69199.14844
# [400]	validation_0-mae:44282.72656	validation_1-mae:44334.95312
# [459]	validation_0-mae:40358.82422	validation_1-mae:39435.40234
# [0]	validation_0-mae:727541.31250	validation_1-mae:921565.81250
# [100]	validation_0-mae:277455.62500	validation_1-mae:379404.28125
# [200]	validation_0-mae:114515.85938	validation_1-mae:170527.78125
# [300]	validation_0-mae:59797.48828	validation_1-mae:92120.13281
# [400]	validation_0-mae:43419.21875	validation_1-mae:67603.48438
# [459]	validation_0-mae:39739.88281	validation_1-mae:63916.37891
# [0]	validation_0-mae:736312.50000	validation_1-mae:980628.43750
# [100]	validation_0-mae:280296.59375	validation_1-mae:412936.46875
# [200]	validation_0-mae:115016.43750	validation_1-mae:196039.62500
# [300]	validation_0-mae:59990.12109	validation_1-mae:130544.30469
# [400]	validation_0-mae:44062.37109	validation_1-mae:111457.42969
# [459]	validation_0-mae:40277.22656	validation_1-mae:106454.47656
# [0]	validation_0-mae:746885.56250	validation_1-mae:932618.68750
# [100]	validation_0-mae:283774.90625	validation_1-mae:344659.03125
# [200]	validation_0-mae:116344.75781	validation_1-mae:126275.47656
# [300]	validation_0-mae:61703.76953	validation_1-mae:51013.14453
# [400]	validation_0-mae:46375.99219	validation_1-mae:53496.87891
# [459]	validation_0-mae:42808.06641	validation_1-mae:54849.59766
# [0]	validation_0-mae:754623.25000	validation_1-mae:936374.75000
# [100]	validation_0-mae:286241.31250	validation_1-mae:362706.40625
# [200]	validation_0-mae:116904.48438	validation_1-mae:140786.79688
# [300]	validation_0-mae:61821.70312	validation_1-mae:63229.58203
# [400]	validation_0-mae:46203.22266	validation_1-mae:54485.19922
# [459]	validation_0-mae:42576.36328	validation_1-mae:53113.14453

# %%
plt.plot(y_test)

# %%
plt.plot(y_pred)

# %%
print(f'Score across folds {np.mean(scores):0.4f}')
print(f'Fold scores:{scores}')
# Out:
# Score across folds 92592.9128
# Fold scores:[129618.35009637885, 63459.00565697836, 60855.23274068962, 106575.91193766177, 147102.4164640553, 71530.77920725504, 69008.6935458452]

# %%
FEATURES = ['MONTH', 'lag1','lag2']
TARGET = '도시가스(톤)_민수용'

X_all = civil[FEATURES]
y_all = civil[TARGET]

reg = xgb.XGBRegressor(base_score=0.5,
                       booster='gbtree',    
                       n_estimators=460,
                       objective='reg:squarederror',
                       max_depth=3,
                       eval_metric='mae',
                       learning_rate=0.01)
reg.fit(X_all, y_all,
        eval_set=[(X_all, y_all)],
        verbose=100)
# Out:
# [0]	validation_0-mae:761865.62500
# [100]	validation_0-mae:288556.46875
# [200]	validation_0-mae:117106.30469
# [300]	validation_0-mae:61244.23828
# [400]	validation_0-mae:46442.62500
# [459]	validation_0-mae:43208.10156
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              eval_metric='mae', gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=460, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
civil.index.max()
# Out:
# Timestamp('2020-12-01 00:00:00')

# %%
future = pd.date_range('2021-01-01','2021-12-01', freq='MS')
future_civil = pd.DataFrame(index=future)
future_civil['MONTH'] = future.month
future_civil['isFuture'] = True
civil['isFuture'] = False
civil_and_future = pd.concat([civil, future_civil])
civil_and_future = add_lags(civil_and_future)
print(civil_and_future)
# Out:
#               YEAR  MONTH  도시가스(톤)_민수용       lag1       lag2  isFuture
# 1996-01-01  1996.0      1     605519.0        NaN        NaN     False
# 1996-02-01  1996.0      2     566323.0        NaN        NaN     False
# 1996-03-01  1996.0      3     477514.0        NaN        NaN     False
# 1996-04-01  1996.0      4     337794.0        NaN        NaN     False
# 1996-05-01  1996.0      5     184522.0        NaN        NaN     False
# ...            ...    ...          ...        ...        ...       ...
# 2021-08-01     NaN      8          NaN   398661.0   374639.0      True
# 2021-09-01     NaN      9          NaN   380235.0   366621.0      True
# 2021-10-01     NaN     10          NaN   616682.0   520739.0      True
# 2021-11-01     NaN     11          NaN  1093747.0  1055013.0      True
# 2021-12-01     NaN     12          NaN  1921404.0  1732147.0      True
#
# [312 rows x 6 columns]

# %%
future_w_features = civil_and_future.query('isFuture').copy()
print(future_w_features)
# Out:
#             YEAR  MONTH  도시가스(톤)_민수용       lag1       lag2  isFuture
# 2021-01-01   NaN      1          NaN  1819123.0  2023662.0      True
# 2021-02-01   NaN      2          NaN  1604680.0  1660132.0      True
# 2021-03-01   NaN      3          NaN  1243141.0  1279302.0      True
# 2021-04-01   NaN      4          NaN   918206.0   920035.0      True
# 2021-05-01   NaN      5          NaN   539517.0   548871.0      True
# 2021-06-01   NaN      6          NaN   406010.0   419341.0      True
# 2021-07-01   NaN      7          NaN   399937.0   403664.0      True
# 2021-08-01   NaN      8          NaN   398661.0   374639.0      True
# 2021-09-01   NaN      9          NaN   380235.0   366621.0      True
# 2021-10-01   NaN     10          NaN   616682.0   520739.0      True
# 2021-11-01   NaN     11          NaN  1093747.0  1055013.0      True
# 2021-12-01   NaN     12          NaN  1921404.0  1732147.0      True

# %%
future_w_features['pred'] = reg.predict(future_w_features[FEATURES])

# %%
#print(future_w_features['pred'])
#print(future_w_features.index)
civil_and_future.loc[future_w_features.index, '도시가스(톤)_민수용']=future_w_features['pred']
civil_and_future['isFuture'] = False
print(civil_and_future)
# Out:
#               YEAR  MONTH   도시가스(톤)_민수용       lag1       lag2  isFuture
# 1996-01-01  1996.0      1  6.055190e+05        NaN        NaN     False
# 1996-02-01  1996.0      2  5.663230e+05        NaN        NaN     False
# 1996-03-01  1996.0      3  4.775140e+05        NaN        NaN     False
# 1996-04-01  1996.0      4  3.377940e+05        NaN        NaN     False
# 1996-05-01  1996.0      5  1.845220e+05        NaN        NaN     False
# ...            ...    ...           ...        ...        ...       ...
# 2021-08-01     NaN      8  4.096708e+05   398661.0   374639.0     False
# 2021-09-01     NaN      9  4.096708e+05   380235.0   366621.0     False
# 2021-10-01     NaN     10  6.311059e+05   616682.0   520739.0     False
# 2021-11-01     NaN     11  1.042514e+06  1093747.0  1055013.0     False
# 2021-12-01     NaN     12  1.749837e+06  1921404.0  1732147.0     False
#
# [312 rows x 6 columns]

# %%
def hyun_pred(start, finish):
    global civil_and_future
    future = pd.date_range(start, finish, freq='MS')
    future_civil = pd.DataFrame(index=future)
    future_civil['MONTH'] = future.month
    future_civil['isFuture'] = True
    civil_and_future = pd.concat([civil_and_future, future_civil])
    civil_and_future = add_lags(civil_and_future)

    future_w_features = civil_and_future.query('isFuture').copy()
    future_w_features['pred'] = reg.predict(future_w_features[FEATURES])
    civil_and_future.loc[future_w_features.index, '도시가스(톤)_민수용']=future_w_features['pred']
    civil_and_future['isFuture'] = False

    return civil_and_future

# %%
for i in pd.date_range('2022-01-01', '2035-01-01',freq='AS'):
    for j in pd.date_range(i, periods=12, freq='MS'):
        continue
    civil_and_future = hyun_pred(i, j)
    print(civil_and_future.head())
    print(civil_and_future.tail())
# Out:
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1       lag2  isFuture
# 2022-08-01   NaN      8  4.210384e+05  4.096708e+05   398661.0     False
# 2022-09-01   NaN      9  4.210384e+05  4.096708e+05   380235.0     False
# 2022-10-01   NaN     10  7.146121e+05  6.311059e+05   616682.0     False
# 2022-11-01   NaN     11  1.034082e+06  1.042514e+06  1093747.0     False
# 2022-12-01   NaN     12  1.738897e+06  1.749837e+06  1921404.0     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2023-08-01   NaN      8  4.210384e+05  4.210384e+05  4.096708e+05     False
# 2023-09-01   NaN      9  4.210384e+05  4.210384e+05  4.096708e+05     False
# 2023-10-01   NaN     10  7.440755e+05  7.146121e+05  6.311059e+05     False
# 2023-11-01   NaN     11  1.034082e+06  1.034082e+06  1.042514e+06     False
# 2023-12-01   NaN     12  1.741438e+06  1.738897e+06  1.749837e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2024-08-01   NaN      8  4.395810e+05  4.210384e+05  4.210384e+05     False
# 2024-09-01   NaN      9  4.395810e+05  4.210384e+05  4.210384e+05     False
# 2024-10-01   NaN     10  7.919304e+05  7.440755e+05  7.146121e+05     False
# 2024-11-01   NaN     11  1.034502e+06  1.034082e+06  1.034082e+06     False
# 2024-12-01   NaN     12  1.741438e+06  1.741438e+06  1.738897e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2025-08-01   NaN      8  4.724194e+05  4.395810e+05  4.210384e+05     False
# 2025-09-01   NaN      9  4.724194e+05  4.395810e+05  4.210384e+05     False
# 2025-10-01   NaN     10  8.608101e+05  7.919304e+05  7.440755e+05     False
# 2025-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034082e+06     False
# 2025-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2026-08-01   NaN      8  4.952107e+05  4.724194e+05  4.395810e+05     False
# 2026-09-01   NaN      9  4.952107e+05  4.724194e+05  4.395810e+05     False
# 2026-10-01   NaN     10  9.080101e+05  8.608101e+05  7.919304e+05     False
# 2026-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2026-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2027-08-01   NaN      8  4.952107e+05  4.952107e+05  4.724194e+05     False
# 2027-09-01   NaN      9  4.952107e+05  4.952107e+05  4.724194e+05     False
# 2027-10-01   NaN     10  9.137842e+05  9.080101e+05  8.608101e+05     False
# 2027-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2027-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2028-08-01   NaN      8  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2028-09-01   NaN      9  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2028-10-01   NaN     10  9.367454e+05  9.137842e+05  9.080101e+05     False
# 2028-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2028-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2029-08-01   NaN      8  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2029-09-01   NaN      9  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2029-10-01   NaN     10  9.367454e+05  9.367454e+05  9.137842e+05     False
# 2029-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2029-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2030-08-01   NaN      8  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2030-09-01   NaN      9  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2030-10-01   NaN     10  9.367454e+05  9.367454e+05  9.367454e+05     False
# 2030-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2030-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2031-08-01   NaN      8  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2031-09-01   NaN      9  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2031-10-01   NaN     10  9.367454e+05  9.367454e+05  9.367454e+05     False
# 2031-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2031-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2032-08-01   NaN      8  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2032-09-01   NaN      9  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2032-10-01   NaN     10  9.367454e+05  9.367454e+05  9.367454e+05     False
# 2032-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2032-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2033-08-01   NaN      8  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2033-09-01   NaN      9  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2033-10-01   NaN     10  9.367454e+05  9.367454e+05  9.367454e+05     False
# 2033-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2033-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2034-08-01   NaN      8  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2034-09-01   NaN      9  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2034-10-01   NaN     10  9.367454e+05  9.367454e+05  9.367454e+05     False
# 2034-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2034-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2035-08-01   NaN      8  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2035-09-01   NaN      9  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2035-10-01   NaN     10  9.367454e+05  9.367454e+05  9.367454e+05     False
# 2035-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2035-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False

# %%
print(civil_and_future.head())
# Out:
#               YEAR  MONTH  도시가스(톤)_민수용  lag1  lag2  isFuture
# 1996-01-01  1996.0      1     605519.0   NaN   NaN     False
# 1996-02-01  1996.0      2     566323.0   NaN   NaN     False
# 1996-03-01  1996.0      3     477514.0   NaN   NaN     False
# 1996-04-01  1996.0      4     337794.0   NaN   NaN     False
# 1996-05-01  1996.0      5     184522.0   NaN   NaN     False

# %%
print(civil_and_future.iloc[324:372])
civil_and_future = civil_and_future.cumsum(1)
civil_and_future['도시가스(톤)_민수용'].plot(xlim=[300,800])
plt.show()
# Out:
#             YEAR  MONTH   도시가스(톤)_민수용          lag1          lag2  isFuture
# 2023-01-01   NaN      1  1.991077e+06  1.875445e+06  1.833040e+06     False
# 2023-02-01   NaN      2  1.629446e+06  1.645894e+06  1.642870e+06     False
# 2023-03-01   NaN      3  1.233613e+06  1.233613e+06  1.233613e+06     False
# 2023-04-01   NaN      4  9.313156e+05  9.313156e+05  9.313156e+05     False
# 2023-05-01   NaN      5  5.090350e+05  5.105064e+05  5.105064e+05     False
# 2023-06-01   NaN      6  4.724194e+05  4.538768e+05  4.282133e+05     False
# 2023-07-01   NaN      7  4.210384e+05  4.210384e+05  4.096708e+05     False
# 2023-08-01   NaN      8  4.210384e+05  4.210384e+05  4.096708e+05     False
# 2023-09-01   NaN      9  4.210384e+05  4.210384e+05  4.096708e+05     False
# 2023-10-01   NaN     10  7.440755e+05  7.146121e+05  6.311059e+05     False
# 2023-11-01   NaN     11  1.034082e+06  1.034082e+06  1.042514e+06     False
# 2023-12-01   NaN     12  1.741438e+06  1.738897e+06  1.749837e+06     False
# 2024-01-01   NaN      1  1.991077e+06  1.991077e+06  1.875445e+06     False
# 2024-02-01   NaN      2  1.644006e+06  1.629446e+06  1.645894e+06     False
# 2024-03-01   NaN      3  1.233613e+06  1.233613e+06  1.233613e+06     False
# 2024-04-01   NaN      4  9.313156e+05  9.313156e+05  9.313156e+05     False
# 2024-05-01   NaN      5  5.090350e+05  5.090350e+05  5.105064e+05     False
# 2024-06-01   NaN      6  4.952107e+05  4.724194e+05  4.538768e+05     False
# 2024-07-01   NaN      7  4.395810e+05  4.210384e+05  4.210384e+05     False
# 2024-08-01   NaN      8  4.395810e+05  4.210384e+05  4.210384e+05     False
# 2024-09-01   NaN      9  4.395810e+05  4.210384e+05  4.210384e+05     False
# 2024-10-01   NaN     10  7.919304e+05  7.440755e+05  7.146121e+05     False
# 2024-11-01   NaN     11  1.034502e+06  1.034082e+06  1.034082e+06     False
# 2024-12-01   NaN     12  1.741438e+06  1.741438e+06  1.738897e+06     False
# 2025-01-01   NaN      1  1.912419e+06  1.991077e+06  1.991077e+06     False
# 2025-02-01   NaN      2  1.644006e+06  1.644006e+06  1.629446e+06     False
# 2025-03-01   NaN      3  1.233613e+06  1.233613e+06  1.233613e+06     False
# 2025-04-01   NaN      4  9.313156e+05  9.313156e+05  9.313156e+05     False
# 2025-05-01   NaN      5  5.090350e+05  5.090350e+05  5.090350e+05     False
# 2025-06-01   NaN      6  4.952107e+05  4.952107e+05  4.724194e+05     False
# 2025-07-01   NaN      7  4.724194e+05  4.395810e+05  4.210384e+05     False
# 2025-08-01   NaN      8  4.724194e+05  4.395810e+05  4.210384e+05     False
# 2025-09-01   NaN      9  4.724194e+05  4.395810e+05  4.210384e+05     False
# 2025-10-01   NaN     10  8.608101e+05  7.919304e+05  7.440755e+05     False
# 2025-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034082e+06     False
# 2025-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
# 2026-01-01   NaN      1  1.912419e+06  1.912419e+06  1.991077e+06     False
# 2026-02-01   NaN      2  1.644006e+06  1.644006e+06  1.644006e+06     False
# 2026-03-01   NaN      3  1.233613e+06  1.233613e+06  1.233613e+06     False
# 2026-04-01   NaN      4  9.313156e+05  9.313156e+05  9.313156e+05     False
# 2026-05-01   NaN      5  5.090350e+05  5.090350e+05  5.090350e+05     False
# 2026-06-01   NaN      6  4.952107e+05  4.952107e+05  4.952107e+05     False
# 2026-07-01   NaN      7  4.952107e+05  4.724194e+05  4.395810e+05     False
# 2026-08-01   NaN      8  4.952107e+05  4.724194e+05  4.395810e+05     False
# 2026-09-01   NaN      9  4.952107e+05  4.724194e+05  4.395810e+05     False
# 2026-10-01   NaN     10  9.080101e+05  8.608101e+05  7.919304e+05     False
# 2026-11-01   NaN     11  1.034502e+06  1.034502e+06  1.034502e+06     False
# 2026-12-01   NaN     12  1.741438e+06  1.741438e+06  1.741438e+06     False
